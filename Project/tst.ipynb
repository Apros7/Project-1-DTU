# %%
# if not intValue.isnumeric(): print("u need to type a number"); return None
# intValue = int(value)
from main import *
import numpy as np

data = []
matrix = [i.strip() for i in open("testfile.csv", "r").readlines()]

for row in matrix:
    t, g, b = row.split()
    t = int(t)
    g = float(g)
    b = int(b)
    data.append([t,g,b])
data = np.array(data)

# data[:,2] == 1
dataPlot(dataLoad("testfile.csv"))
# Out:
# dict_values(['Salmonella enterica', 'Bacillus cereus', 'Listeria', 'Brochothrix thermosphacta'])
# ['Salmonella enterica', 'Bacillus cereus', 'Listeria', 'Brochothrix thermosphacta']
